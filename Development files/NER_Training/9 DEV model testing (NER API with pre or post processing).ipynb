# %%
import requests
import json
import pandas as pd
import time

# %%
env_data = {"dev":{
  "sbertURL": "https://gst-sbert-model-dev.southcentralus.inference.ml.azure.com/score",
  "sbertAPIKey": "<SBERT_API_KEY_DEV>",
  "elasticSearchURL": "https://elast-gst-nprd-ussc-01.es.privatelink.southcentralus.azure.elastic-cloud.com:9243",
  "elasticSearchPassword": "<ELASTICSEARCH_PASSWORD_DEV>",
  "nerURL": "https://gst-ner-endpoint-dev.southcentralus.inference.ml.azure.com/score",
  "nerAPIKey": "<AML_ENDPOINT_KEY_DEV>",
  },
"qa":{
  "sbertURL": "https://gst-sbert-model-qa.southcentralus.inference.ml.azure.com/score",
  "sbertAPIKey":"<SBERT_API_KEY_QA>",
  "elasticSearchURL": "https://elast-gst-tst-ussc-01.es.privatelink.southcentralus.azure.elastic-cloud.com:9243",
  "elasticSearchPassword": "<ELASTICSEARCH_PASSWORD_QA>",
  "nerURL": "https://gst-ner-endpoint-qa.southcentralus.inference.ml.azure.com/score",
  "nerAPIKey": "<AML_ENDPOINT_KEY_QA>",
  },
"prod":{
  "sbertURL": "https://gst-sbert-model-prod.southcentralus.inference.ml.azure.com/score",
  "sbertAPIKey":"<SBERT_API_KEY_PROD>",
  "elasticSearchURL": "https://elast-gst-prd-ussc-01.es.privatelink.southcentralus.azure.elastic-cloud.com:9243",
  "elasticSearchPassword": "<ELASTICSEARCH_PASSWORD_PROD>",
  "nerURL": "https://gst-ner-endpoint-prod.southcentralus.inference.ml.azure.com/score",
  "nerAPIKey": "<AML_ENDPOINT_KEY_PROD>",
  }}

# %%
def call_ml_studio_api(q, env):
    url = env_data[env]['nerURL']
    key = env_data[env]['nerAPIKey']

    headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ key), 'azureml-model-deployment': 'blue' }

    data = { "data": q}
    body = str.encode(json.dumps(data))
    
    try:
        response = requests.post(url, headers=headers, json=data)
        output = response.json()
    except Exception as e:
        print(q)
        print(e)
        output = {}
    
    return output

# %%
query = "BJEV"
call_ml_studio_api(query, 'dev')
# Out:
# {'userInput': {'searchQuery': 'BJEV'},
#  'modelOutput': {'entities': {'GRADE': [],
#    'APPLICATION': [],
#    'BRAND': [],
#    'POLYMER': [],
#    'PROPERTY': [],
#    'FILLER': [],
#    'FEATURE': [],
#    'PROCESSING': [],
#    'DELIVERY_FORM': [],
#    'COMPETITOR_GRADE': [],
#    'AUTO_CERT': [{'oem': 'baic', 'certs': ['bjev']}],
#    'RAILWAY_CERT': [],
#    'WATER_CERT': [],
#    'NSF_CERT': [],
#    'INDUSTRY': [],
#    'REGION': []},
#   'unidentified': '',
#   'outOfScope': {'active': False,
#    'entities': {'GRADE': [],
#     'BRAND': [],
#     'POLYMER': [],
#     'FILLER': [],
#     'OTHERS': []}}},
#  'modelVersion': 'GPT4o-mini-11_27_24',
#  'apiVersion': 'v4.3.5'}

# %%
def call_ml_studio_api(q, env):
    url = env_data[env]['nerURL']
    key = env_data[env]['nerAPIKey']

    headers = {'Content-Type':'application/json', 'Authorization':('Bearer '+ key), 'azureml-model-deployment': 'blue' }

    data = { "data": q}
    body = str.encode(json.dumps(data))
    
    try:
        response = requests.post(url, headers=headers, json=data)
        output = response.json()
    except Exception as e:
        print(q)
        print(e)
        output = {}
    
    return output

# %%
query = "carbon footprint"
call_ml_studio_api(query, 'dev')
# Out:
# {'userInput': {'searchQuery': 'carbon footprint'},
#  'modelOutput': {'entities': {'GRADE': [],
#    'APPLICATION': [],
#    'BRAND': [],
#    'POLYMER': [],
#    'PROPERTY': [],
#    'FILLER': [],
#    'FEATURE': ['carbon capture'],
#    'PROCESSING': [],
#    'DELIVERY_FORM': [],
#    'COMPETITOR_GRADE': [],
#    'AUTO_CERT': [],
#    'RAILWAY_CERT': [],
#    'WATER_CERT': [],
#    'NSF_CERT': [],
#    'INDUSTRY': [],
#    'REGION': []},
#   'unidentified': '',
#   'outOfScope': {'active': False,
#    'entities': {'GRADE': [],
#     'BRAND': [],
#     'POLYMER': [],
#     'FILLER': [],
#     'OTHERS': []}}},
#  'modelVersion': 'GPT4o-mini-11_27_24',
#  'apiVersion': 'v4.3.5'}

# %%
query = "ford"
call_ml_studio_api(query, 'dev')
# Out:
# {'userInput': {'searchQuery': 'ford'},
#  'modelOutput': {'entities': {'GRADE': [],
#    'APPLICATION': [],
#    'BRAND': [],
#    'POLYMER': [],
#    'PROPERTY': [],
#    'FILLER': [],
#    'FEATURE': [],
#    'PROCESSING': [],
#    'DELIVERY_FORM': [],
#    'COMPETITOR_GRADE': [],
#    'AUTO_CERT': [{'oem': 'ford', 'certs': ['all']}],
#    'RAILWAY_CERT': [],
#    'WATER_CERT': [],
#    'NSF_CERT': [],
#    'INDUSTRY': [],
#    'REGION': []},
#   'unidentified': '',
#   'outOfScope': {'active': False,
#    'entities': {'GRADE': [],
#     'BRAND': [],
#     'POLYMER': [],
#     'FILLER': [],
#     'OTHERS': []}}},
#  'modelVersion': 'GPT4o-mini-11_27_24',
#  'apiVersion': 'v4.3.5'}

# %%
query = "water certification at 23C"
call_ml_studio_api(query, 'dev')
# Out:
# {'userInput': {'searchQuery': 'water certification at 23C'},
#  'modelOutput': {'entities': {'GRADE': [],
#    'APPLICATION': [],
#    'BRAND': [],
#    'POLYMER': [],
#    'PROPERTY': [],
#    'FILLER': [],
#    'FEATURE': [],
#    'PROCESSING': [],
#    'DELIVERY_FORM': [],
#    'COMPETITOR_GRADE': [],
#    'AUTO_CERT': [],
#    'RAILWAY_CERT': [],
#    'WATER_CERT': [{'standard': 'all', 'temp': ['23']}],
#    'NSF_CERT': [],
#    'INDUSTRY': [],
#    'REGION': []},
#   'unidentified': '',
#   'outOfScope': {'active': False,
#    'entities': {'GRADE': [],
#     'BRAND': [],
#     'POLYMER': [],
#     'FILLER': [],
#     'OTHERS': []}}},
#  'modelVersion': 'GPT4o-mini-11_27_24',
#  'apiVersion': 'v4.3.5'}

# %%
query = "li auto and ford"
call_ml_studio_api(query, 'dev')
# Out:
# {'userInput': {'searchQuery': 'li auto and ford'},
#  'modelOutput': {'entities': {'GRADE': [],
#    'APPLICATION': [],
#    'BRAND': [],
#    'POLYMER': [],
#    'PROPERTY': [],
#    'FILLER': [],
#    'FEATURE': [],
#    'PROCESSING': [],
#    'DELIVERY_FORM': [],
#    'COMPETITOR_GRADE': [],
#    'AUTO_CERT': [{'oem': 'li auto', 'certs': ['all']},
#     {'oem': 'ford', 'certs': ['all']}],
#    'RAILWAY_CERT': [],
#    'WATER_CERT': [],
#    'NSF_CERT': [],
#    'INDUSTRY': [],
#    'REGION': []},
#   'unidentified': '',
#   'outOfScope': {'active': False,
#    'entities': {'GRADE': [],
#     'BRAND': [],
#     'POLYMER': [],
#     'FILLER': [],
#     'OTHERS': []}}},
#  'modelVersion': 'GPT4o-mini-11_27_24',
#  'apiVersion': 'v4.3.5'}

# %%
query = "IMDS 121-73W175" # imds should be removed from the grade name
call_ml_studio_api(query, 'dev')
# Out:
# {'userInput': {'searchQuery': 'IMDS 121-73W175'},
#  'modelOutput': {'entities': {'GRADE': ['121-73w175'],
#    'APPLICATION': [],
#    'BRAND': [],
#    'POLYMER': [],
#    'PROPERTY': [],
#    'FILLER': [],
#    'FEATURE': [],
#    'PROCESSING': [],
#    'DELIVERY_FORM': [],
#    'COMPETITOR_GRADE': [],
#    'AUTO_CERT': [],
#    'RAILWAY_CERT': [],
#    'WATER_CERT': [],
#    'NSF_CERT': [],
#    'INDUSTRY': [],
#    'REGION': []},
#   'unidentified': '',
#   'outOfScope': {'active': False,
#    'entities': {'GRADE': [],
#     'BRAND': [],
#     'POLYMER': [],
#     'FILLER': [],
#     'OTHERS': []}}},
#  'modelVersion': 'GPT4o-mini-11_27_24',
#  'apiVersion': 'v4.3.5'}

# %%
query = "NW-02" # comp grade
call_ml_studio_api(query, 'dev')
# Out:
# {'userInput': {'searchQuery': 'NW-02'},
#  'modelOutput': {'entities': {'GRADE': [],
#    'APPLICATION': [],
#    'BRAND': [],
#    'POLYMER': [],
#    'PROPERTY': [],
#    'FILLER': [],
#    'FEATURE': [],
#    'PROCESSING': [],
#    'DELIVERY_FORM': [],
#    'COMPETITOR_GRADE': ['nw-02'],
#    'AUTO_CERT': [],
#    'RAILWAY_CERT': [],
#    'WATER_CERT': [],
#    'NSF_CERT': [],
#    'INDUSTRY': [],
#    'REGION': []},
#   'unidentified': '',
#   'outOfScope': {'active': False,
#    'entities': {'GRADE': [],
#     'BRAND': [],
#     'POLYMER': [],
#     'FILLER': [],
#     'OTHERS': []}}},
#  'modelVersion': 'GPT4o-mini-11_27_24',
#  'apiVersion': 'v4.3.5'}

# %%
query = "PA46"
call_ml_studio_api(query, 'dev')
# Out:
# {'userInput': {'searchQuery': 'PA46'},
#  'modelOutput': {'entities': {'GRADE': [],
#    'APPLICATION': [],
#    'BRAND': [],
#    'POLYMER': ['pa46'],
#    'PROPERTY': [],
#    'FILLER': [],
#    'FEATURE': [],
#    'PROCESSING': [],
#    'DELIVERY_FORM': [],
#    'COMPETITOR_GRADE': [],
#    'AUTO_CERT': [],
#    'RAILWAY_CERT': [],
#    'WATER_CERT': [],
#    'NSF_CERT': [],
#    'INDUSTRY': [],
#    'REGION': []},
#   'unidentified': '',
#   'outOfScope': {'active': False,
#    'entities': {'GRADE': [],
#     'BRAND': [],
#     'POLYMER': [],
#     'FILLER': [],
#     'OTHERS': []}}},
#  'modelVersion': 'GPT4o-mini-11_27_24',
#  'apiVersion': 'v4.3.5'}

# %%
query = "hr grade" # "hr" should be "hr" only. Chemille should return "Hydrolysis resistant" or "Heat stabilized or stable to heat"
call_ml_studio_api(query, 'dev')
# Out:
# {'userInput': {'searchQuery': 'hr grade'},
#  'modelOutput': {'entities': {'GRADE': [],
#    'APPLICATION': [],
#    'BRAND': [],
#    'POLYMER': [],
#    'PROPERTY': [],
#    'FILLER': [],
#    'FEATURE': ['hr'],
#    'PROCESSING': [],
#    'DELIVERY_FORM': [],
#    'COMPETITOR_GRADE': [],
#    'AUTO_CERT': [],
#    'RAILWAY_CERT': [],
#    'WATER_CERT': [],
#    'NSF_CERT': [],
#    'INDUSTRY': [],
#    'REGION': []},
#   'unidentified': '',
#   'outOfScope': {'active': False,
#    'entities': {'GRADE': [],
#     'BRAND': [],
#     'POLYMER': [],
#     'FILLER': [],
#     'OTHERS': []}}},
#  'modelVersion': 'GPT4o-mini-11_27_24',
#  'apiVersion': 'v4.3.5'}
