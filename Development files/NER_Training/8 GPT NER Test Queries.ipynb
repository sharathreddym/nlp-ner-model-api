# %%
# # for testing the model
# set HTTPS_PROXY=czgdcsdwankerb1.czds.bz:8080
# pip install --upgrade openai
# set HTTPS_PROXY=

# %%
#USNC
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

from openai import AzureOpenAI
import time
import json
import pandas as pd

import ast
import re

# %%
client = AzureOpenAI(
    api_key=os.getenv('open_api_key'),  
    api_version="2024-02-01",
    azure_endpoint=os.getenv('open_api_base'),
)

# %% [markdown]
# ### Using finetuned model

# %%
# deployment1 = "oai-gpt-4o-mini-NER_30_08_24_Test-gst-d-usnc-01"
# deployment1 = "oai-gpt-4o-mini-NER-17-09-24-gst-d-usnc-01"
# deployment1 = "oai-gpt-4o-mini-NER-2024-10-21-gst-d-usnc-01"
deployment1 = "oai-gpt-4o-mini-NER-2024-11-27-gst-d-usnc-01"
# deployment1 = "oai-gpt-4o-mini-NER-2024-11-28-gst-d-usnc-01"
# deployment1 = "oai-gpt-4o-mini-NER-2024-10-23-gst-d-usnc-01"
# deployment1 = "oai-gpt-4o-mini-NER-2024-09-19-gst-d-usnc-01"
# deployment1 = "oai-gpt35-NER_30_08_24_Test-gst-d-usnc-01"
# deployment1 = "oai-gpt35-NER_05_09_24-gst-d-usnc-01"
# deployment1 = "oai-gpt35-NER_06_09_24-gst-d-usnc-01"
# deployment1 = "oai-gpt35-NERv14e3-gst-d-usnc-01"
# deployment1 = "oai-gpt35-NER24-06-gst-d-usnc-01"

# deployment1 = "oai-gpt35-NERv14e3-gst-d-usnc-01"

content = "Act as an NER model trained on the data corpus of 'Celanese' which is a global chemical leader in the production of differentiated chemistry solutions and specialty materials used in most major industries and consumer applications. Ensure the output is a structured dictionary format."

# %%
def get_ner_gpt(query, t=0.01):
    completion = client.chat.completions.create(
        seed=12,
        temperature = t,
        model=deployment1,
        messages=[
            {"role": "system", "content": content}, 
            {"role": "user", "content": query},
            ],
        )

    return completion.choices[0].message.content

# %%
# def get_ner_gpt(query):
#     completion = client.chat.completions.create(
#         seed=12,
#         temperature = 0.1,
#         model=deployment1,
        
#         messages=[
#             {"role": "system", "content": content}, 
            
#             # {"role": "user", "content": "ford and nsf 61 certifcations"}, # input
#             # {"role": "assistant", "content": "{'GRADE': [], 'APPLICATION': [], 'BRAND': [], 'POLYMER': [], 'PROPERTY': [], 'FILLER': [], 'FEATURE': [], 'PROCESSING': [], 'DELIVERY_FORM': [], 'COMPETITOR_GRADE': [], 'AUTO_CERT': [{'oem': 'ford', 'certs': ['all']}], 'RAILWAY_CERT': [], 'WATER_CERT': [], 'NSF_CERT': ['nsf 61']}"}, # output
            
#             # {"role": "user", "content": "15702"}, # input
#             # {"role": "assistant", "content": "{'GRADE': [], 'APPLICATION': [], 'BRAND': [], 'POLYMER': [], 'PROPERTY': [], 'FILLER': [], 'FEATURE': [], 'PROCESSING': [], 'DELIVERY_FORM': [], 'COMPETITOR_GRADE': [], 'AUTO_CERT': [{'oem': 'general motors (gm)', 'certs': ['15702']}], 'RAILWAY_CERT': [], 'WATER_CERT': [], 'NSF_CERT': []}"}, # output

#             # {"role": "user", "content": "pa6t+gf35"}, # input
#             # {"role": "assistant", "content": "{'GRADE': [], 'APPLICATION': [], 'BRAND': [], 'POLYMER': ['pa6t'], 'PROPERTY': [], 'FILLER': [{'filler_name': ['glass fiber']}, {'total_load': {'value': '35', 'min': '30', 'max': '40'}}], 'FEATURE': [], 'PROCESSING': [], 'DELIVERY_FORM': [], 'COMPETITOR_GRADE': [], 'AUTO_CERT': [], 'RAILWAY_CERT': [], 'WATER_CERT': [], 'NSF_CERT': []}"}, # output

#             # {"role": "user", "content": "nylbond"}, # input
#             # {"role": "assistant", "content": "{'GRADE': [], 'APPLICATION': ['nylbond'], 'BRAND': [], 'POLYMER': [], 'PROPERTY': [], 'FILLER': [], 'FEATURE': [], 'PROCESSING': [], 'DELIVERY_FORM': [], 'COMPETITOR_GRADE': [], 'AUTO_CERT': [], 'RAILWAY_CERT': [], 'WATER_CERT': [], 'NSF_CERT': []}"}, # output

#             # {"role": "user", "content": "nb impact"}, # input
#             # {"role": "assistant", "content": "{'GRADE': [], 'APPLICATION': [], 'BRAND': [], 'POLYMER': [], 'PROPERTY': [{'property_name': 'charpy impact strength', 'modifier': {'value': 'nb', 'min': None, 'max': None, 'unit': ''}, 'property_type': 'property'}], 'FILLER': [], 'FEATURE': [], 'PROCESSING': [], 'DELIVERY_FORM': [], 'COMPETITOR_GRADE': [], 'AUTO_CERT': [], 'RAILWAY_CERT': [], 'WATER_CERT': [], 'NSF_CERT': []}"}, # output

#             # {"role": "user", "content": "conductive"}, # input
#             # {"role": "assistant", "content": "{'GRADE': [], 'APPLICATION': [], 'BRAND': [], 'POLYMER': [], 'PROPERTY': [], 'FILLER': [], 'FEATURE': ['conductivity'], 'PROCESSING': [], 'DELIVERY_FORM': [], 'COMPETITOR_GRADE': [], 'AUTO_CERT': [], 'RAILWAY_CERT': [], 'WATER_CERT': [], 'NSF_CERT': []}"}, # output

#             # {"role": "user", "content": "good conductive grade"}, # input
#             # {"role": "assistant", "content": "{'GRADE': [], 'APPLICATION': [], 'BRAND': [], 'POLYMER': [], 'PROPERTY': [], 'FILLER': [], 'FEATURE': ['conductivity'], 'PROCESSING': [], 'DELIVERY_FORM': [], 'COMPETITOR_GRADE': [], 'AUTO_CERT': [], 'RAILWAY_CERT': [], 'WATER_CERT': [], 'NSF_CERT': []}"}, # output

#             # {"role": "user", "content": "good conductive material"}, # input
#             # {"role": "assistant", "content": "{'GRADE': [], 'APPLICATION': [], 'BRAND': [], 'POLYMER': [], 'PROPERTY': [], 'FILLER': [], 'FEATURE': ['conductivity'], 'PROCESSING': [], 'DELIVERY_FORM': [], 'COMPETITOR_GRADE': [], 'AUTO_CERT': [], 'RAILWAY_CERT': [], 'WATER_CERT': [], 'NSF_CERT': []}"}, # output

#             # {"role": "user", "content": "conductive"}, # input
#             # {"role": "assistant", "content": "{'GRADE': [], 'APPLICATION': [], 'BRAND': [], 'POLYMER': [], 'PROPERTY': [], 'FILLER': [], 'FEATURE': ['conductivity'], 'PROCESSING': [], 'DELIVERY_FORM': [], 'COMPETITOR_GRADE': [], 'AUTO_CERT': [], 'RAILWAY_CERT': [], 'WATER_CERT': [], 'NSF_CERT': []}"}, # output

#             # {"role": "user", "content": "good conductive grade"}, # input
#             # {"role": "assistant", "content": "{'GRADE': [], 'APPLICATION': [], 'BRAND': [], 'POLYMER': [], 'PROPERTY': [], 'FILLER': [], 'FEATURE': ['conductivity'], 'PROCESSING': [], 'DELIVERY_FORM': [], 'COMPETITOR_GRADE': [], 'AUTO_CERT': [], 'RAILWAY_CERT': [], 'WATER_CERT': [], 'NSF_CERT': []}"}, # output

#             # {"role": "user", "content": "good conductive material"}, # input
#             # {"role": "assistant", "content": "{'GRADE': [], 'APPLICATION': [], 'BRAND': [], 'POLYMER': [], 'PROPERTY': [], 'FILLER': [], 'FEATURE': ['conductivity'], 'PROCESSING': [], 'DELIVERY_FORM': [], 'COMPETITOR_GRADE': [], 'AUTO_CERT': [], 'RAILWAY_CERT': [], 'WATER_CERT': [], 'NSF_CERT': []}"}, # output
            
#             {"role": "user", "content": query},
            
#             ],
#         )

#     return completion.choices[0].message.content

# %%
def validate_property(properties): 
    for prop in properties:  
        if not isinstance(prop, dict):  
            return False, "Each item in 'PROPERTY' must be a dictionary"  
        if 'property_name' not in prop or 'modifier' not in prop or 'property_type' not in prop:  
            return False, "Each property dictionary must contain 'property_name', 'modifier', and 'property_type' keys"  
        if not isinstance(prop['modifier'], dict):  
            return False, "'modifier' must be a dictionary"  
        for key in ['value', 'min', 'max', 'unit']:  
            if key not in prop['modifier']:  
                return False, f"Missing key '{key}' in modifier"  
    return True, "" 

def validate_filler(fillers): 
    for filler in fillers:  
        if not isinstance(filler, dict):  
            return False, "Each item in 'FILLER' must be a dictionary"  
        if 'filler_name' in filler:  
            if not isinstance(filler['filler_name'], list):  
                return False, "'filler_name' must be a list"  
        elif 'total_load' in filler:  
            if not isinstance(filler['total_load'], dict):  
                return False, "'total_load' must be a dictionary"  
            for key in ['value', 'min', 'max']:  
                if key not in filler['total_load']:  
                    return False, f"Missing key '{key}' in total_load"  
        else:  
            return False, "Each filler dictionary must contain either 'filler_name' or 'total_load'" 
    return True, "" 


def validate_auto_cert(auto_certs):  
    for cert in auto_certs:  
        if not isinstance(cert, dict):  
            return False, "Each item in 'AUTO_CERT' must be a dictionary"  
        if 'oem' not in cert or 'certs' not in cert:  
            return False, "Each auto cert dictionary must contain 'oem' and 'certs'"  
        if not isinstance(cert['certs'], list):  
            return False, "'certs' must be a list"  
    return True, ""  
  
def validate_railway_cert(railway_certs):  
    for cert in railway_certs:  
        if not isinstance(cert, dict):  
            return False, "Each item in 'RAILWAY_CERT' must be a dictionary"  
        if 'standard' not in cert or 'hazard_level' not in cert or 'req_set' not in cert:  
            return False, "Each railway cert dictionary must contain 'standard', 'hazard_level', and 'req_set'"  
        if not isinstance(cert['hazard_level'], list) or not isinstance(cert['req_set'], list):  
            return False, "'hazard_level' and 'req_set' must be lists"  
    return True, ""  
  
def validate_water_cert(water_certs):  
    for cert in water_certs:  
        if not isinstance(cert, dict):  
            return False, "Each item in 'WATER_CERT' must be a dictionary"  
        if 'standard' not in cert or 'temp' not in cert:  
            return False, "Each water cert dictionary must contain 'standard' and 'temp'"  
        if not isinstance(cert['temp'], list):  
            return False, "'temp' must be a list"  
    return True, ""  
  
def validate_nsf_cert(nsf_certs):  
    if not isinstance(nsf_certs, list):  
        return False, "'NSF_CERT' must be a list"  
    return True, ""  
  
def validate_dict(data):   
    expected_format = {  
    'GRADE': list,  
    'APPLICATION': list,  
    'BRAND': list,  
    'POLYMER': list,  
    'PROPERTY': list,  
    'FILLER': list,  
    'FEATURE': list,  
    'PROCESSING': list,  
    'DELIVERY_FORM': list,  
    'COMPETITOR_GRADE': list,  
    'AUTO_CERT': list,  
    'RAILWAY_CERT': list,  
    'WATER_CERT': list,  
    'NSF_CERT': list,  
    'INDUSTRY': list,  
    'REGION': list  
    }  
    
     
    # Find any entities in the input data that are not expected  
    unknown_entities = set(data.keys() - expected_format.keys())
      
    # if unknown_entities and not "CERTIFICATION" in unknown_entities:  
    if unknown_entities:  
        return False, f"Unknown entities detected: {', '.join(unknown_entities)}" 
    
#     if "CERTIFICATION" in unknown_entities and data["CERTIFICATION"]:
# # #     if "CERTIFICATION" in unknown_entities:
#         return False, f"Value found in CERTIFICATION" 
  
    # Check if all required keys are present and of the correct type  
    for key, expected_type in expected_format.items():  
        if key not in data:  
            return False, f"Missing key: {key}"  
        if not isinstance(data[key], expected_type):  
            return False, f"Key '{key}' is not of type {expected_type.__name__}"   
    
    # Validate PROPERTY  
    valid, message = validate_property(data['PROPERTY'])  
    if not valid:  
        return False, message
    
    # Validate FILLER  
    valid, message = validate_filler(data['FILLER'])  
    if not valid:  
        return False, message

  
    # Validate AUTO_CERT  
    valid, message = validate_auto_cert(data['AUTO_CERT'])  
    if not valid:  
        return False, message  
  
    # Validate RAILWAY_CERT  
    valid, message = validate_railway_cert(data['RAILWAY_CERT'])  
    if not valid:  
        return False, message  
  
    # Validate WATER_CERT  
    valid, message = validate_water_cert(data['WATER_CERT'])  
    if not valid:  
        return False, message  
  
    # Validate NSF_CERT  
    valid, message = validate_nsf_cert(data['NSF_CERT'])  
    if not valid:  
        return False, message  
  
    return True, "Validation successful"

# %%
def get_output(q,temperature=0.01):
    st = time.time()
    output = get_ner_gpt(q.lower(), temperature)
    et = time.time() - st
    output = eval(output)
    is_valid, message = validate_dict(output)
    if not is_valid:
        print("Not valid output:", message)
        print(output)
        
    for entity in output:
        if output[entity]:
            print(entity, ": ", output[entity], "\n")

    print(f"Response time: {round(et, 4)}")

# %%
get_output("pom 20") # not a problem
# Out:
# POLYMER :  ['pom']
#
# Response time: 1.2074

# %%
get_output("20 pom")
# Out:
# POLYMER :  ['pom']
#
# Response time: 0.9195

# %%
get_output("20% pom")
get_output("10% pom")
get_output("pps10%")
get_output("pps 40%")
get_output("pom 15%")
# Out:
# POLYMER :  ['pom']
#
# FILLER :  [{'total_load': {'value': '20', 'min': '15', 'max': '25'}}]
#
# Response time: 1.1405
# POLYMER :  ['pom']
#
# FILLER :  [{'total_load': {'value': '10', 'min': '5', 'max': '15'}}]
#
# Response time: 1.0787
# POLYMER :  ['pps']
#
# FILLER :  [{'total_load': {'value': '10', 'min': '5', 'max': '15'}}]
#
# Response time: 1.1259
# POLYMER :  ['pps']
#
# FILLER :  [{'total_load': {'value': '40', 'min': '35', 'max': '45'}}]
#
# Response time: 1.1266
# POLYMER :  ['pom']
#
# FILLER :  [{'total_load': {'value': '15', 'min': '10', 'max': '20'}}]
#
# Response time: 1.1216

# %%
get_output("eva")

# %%
get_output("frianyl zytel Eco-R") # other model is predicting as grade for eco-r

# %%
get_output("tf")

# %%
get_output("pom, gb15, tf")

# %%
get_output("pom, gb15%, tf")

# %%
get_output("Module elastic of 77g33?")

# %%
get_output("PA66 / 6 v2 Tough")

# %%
get_output("PBT LW GF30-V0")

# %%
get_output("booster overmolding")

# %%
get_output("POM NW-02") # post processing will correct it

# %%
get_output("rohs M90")

# %%
get_output("Tecnoprene TCFK6TILE YI")

# %%
get_output("pa 46")
get_output("pa46")
get_output("pa56")

# %%
get_output("anti-static, polyether")

# %%
get_output("similar santoprene grade to  251-7030W")

# %%
get_output("flammabiblity")

# %%
get_output("ultra") #??? # post-processing will handle this query, but if it is complex, model result is wrong and we need to move it to grade/comp grade

# %%
get_output("skoda")

# %%
get_output("low density and tensile mod")

# %%
a = [
 'BAIC',
 'BMW',
 'BYD',
 'Bosch',
 'CATL',
 'Changan',
 'Chery',
 'Continental',
 'Dongfeng Motor',
 'Evergrande Auto',
 'FAW Group',
 'Ford',
 'Geely',
 'General Motors (GM)',
 'Great Wall Motor',
 'Honda',
 'Hyundai',
 'IVECO',
 'Li Auto',
 'MAN',
 'Mercedes-Benz',
 'NIO',
 'Nissan',
 'SAIC Motor',
 'Stellantis-Chrysler',
 'Stellantis-FCA Group',
 'Stellantis-PSA Group',
 'Tesla',
 'VW Group',
 'ZF Group',
]

# %%
for i in a:
    print(i)
    get_output(i)
    print("\n")

# %%
get_output("li apporval")

# %%
get_output("li") # difficult to handle

# %%
get_output("3,000 MPa Tensile 8 Izod")

# %%
get_output("PBT high CTI")

# %%
get_output("amodel")

# %%
get_output("GMW15340P-E/P-M20-T1-Class-P")

# %%
get_output("short glass fiber")

# %%
get_output("121-80w175 sea")

# %%
get_output("ZENYTE")

# %%
get_output("conveyor belt barrel")

# %%
get_output("high density, tensile modulus of 1200")

# %%
get_output("withstands 400 degrees")

# %%
get_output("drinking water PPA") # water cert

# %%
get_output("cx 2003fc, gm spec")

# %%
get_output("pa6GF30 for air intake manifold")

# %%
get_output("50-60 Shore D elastomer with UV94 V0 flame retardance and capable of withstanding 175 degrees C continuously") # elastomer/tpe

# %%
get_output("lcp-gf30 ul listed")

# %%
get_output("LFRT")

# %%
get_output("UNFILLED PBT OFF SET OF celanex 2002-2")

# %%
get_output("pbt hr unfilled")

# %%
get_output("ford")

# %%
get_output("2K moulding PPS") # multi injection molding

# %%
get_output("DBL1232")

# %%
get_output("vw 50134_1A")

# %%
get_output("POM conductive Hostaform")

# %%
get_output("unfilled pps in pellet size  for injection moulding") # ignore 'pellet size', however 'pellet size' and 'pellets' delivery form is confusing and close

# %%
# ID48: Currently, NER is labeling as features, should be labeled as property "impact", value=nb (no break, identified as "n" in data).

# ID126: Upon searching for Halogenated FR grades, non-halogenated grades are recommended (Search term: halogenated flame retardant PA66GF25).

# ID155: NER needs to convert temperature Kelvin (K) to °C

# ID 243: Currently, search bar understands V0 very well, but it seems other ratings are not understood. Need to improve search bar so all flame ratings are understood and mapped correctly (flame ratings = 5VA, 5VB, V0, V1, V2, HB). Search query "UL 5VA" also not working currently.

# ID 249: Currently, if a user searches for "carbon footprint...", NER is returning filler type: carbon fiber. These are very different things. Although carbon footprint is currently out of scope, likely will be included in Chemille in the future. Perhaps as a property (but not positive).

# ID 254: In NER response, application being identified as "fuel cap for ford". Application should be "fuel cap" and auto certification should be OEM "ford".

# %%
get_output("abc")

# %%
get_output("heat resistant abc")
get_output("heat resistant 123")

# %%
get_output("impact nb")

# %%
get_output("nb impact")

# %%
get_output("nb") # property value 'nb' but not important

# %%
get_output("halogenated flame retardant PA66GF25")

# %%
get_output("PE with MI of 463 deg K")

# %%
get_output("MI of 250")

# %%
get_output("UL 5VA")
get_output("UL 5VB")
get_output("UL V0")
get_output("UL V1")
get_output("UL V2")
get_output("UL HB")

# %%
get_output("UL HB40")
get_output("ul HB 40")

# %%
get_output("carbon footprint...")

# %%
get_output("fuel cap for ford")

# %%
get_output("automobiles")

# %%
get_output("railway")

# %%
get_output("heat resistant and non sustainable")

# %%
get_output("POM sheet & profile, food grade FDA and EU10/2011, natural colour")

# %%
get_output("POM, sheet & profile")

# %%
get_output("unfilled FR pbt")

# %%
get_output("unfilled, FR pbt")

# %%
get_output("unfilled FR, pbt")

# %%
get_output("fr")

# %%
get_output("water approvals and railway specs")

# %%
get_output("railway specs") # fail

# %%
get_output("need material to replace aluminium for profiles") # profiles is app here

# %%
get_output("flame rating 2.2mm")

# %%
get_output("us sourced")

# %%
get_output("u.s. sourced")

# %%
get_output("5VA")

# %%
get_output("general motor and nsf 372 certifcations")

# %%
get_output("general motor and nsf 61 certifcations")

# %%
get_output("15702")

# %%
get_output("pa6t+gf30")

# %%
get_output("flexible material with good chemical resistance")

# %%
get_output("charpy impact of nb")

# %%
get_output("good conductive material")

# %%
get_output("impact nb")

# %%
get_output("nb impact unnotched")

# %%
get_output("nb impact notched")

# %%
get_output("ford and nsf 61 certifcations")

# %%
get_output("atleast 14700 mpa flex modulus")

# %%
get_output("pp-gf30 long fiber")

# %%
get_output("gf30 long fiber")

# %%
get_output("cti of 20")

# %%
get_output("ppa flame retard")

# %%
get_output("ppa fr")

# %%
get_output("Find a material that is heat resistant up to 400 degrees")

# %%
get_output("Find a material that withstands 400 degrees")

# %%
get_output("flame rating at 3mm v0")
# get_output("flame rating @ 3mm v0")
# get_output("flame rating v0 @ 5mm")
# get_output("fr at 3mm v0") 
# get_output("fr v2 at 1.2mm")

# %%
get_output("fr at 1.2mm v0")

# %%
get_output("pa66 gf30")

# %%
get_output("flame rating v2 1.2")

# %%
get_output("fr v0 1.2")

# %%
get_output("fr v-0 1.2")

# %%
get_output("fr v-0 1.2cm")

# %%
get_output("mercedes approved dbl 10000")

# %%
get_output("mercedes approved dbl 10000 certification")

# %%
get_output("nylon6/10")

# %%
get_output("food contact PBT unfilled injection molding")

# %%
get_output("high density and tensile modulus 1200")

# %%
get_output("low tensile stress and melting tempertature")

# %%
get_output("low tensile stress and high melting tempertature")

# %%
get_output("get nylon material with condition stress at break more than 190MPA")

# %%
get_output("get nylon material with condition stress at break (tensile) more than 190MPA") # stress at break

# %%
get_output("get nylon material with condition tensile stress at break more than 190MPA") # stress at break

# %%
get_output("I would like to check all grades contain GF less than 30%, V0 haogen free, CTI 0class") # 'comparative tracking index (cti) (ul 746a)'

# %%
get_output("grade with cti plc3")

# %%
get_output("grade with cti high")

# %%
get_output("PA6 GF MF40")

# %%
get_output("POM Extrusion grade for sheet & profile, food grade FDA and EU10/2011, natural colour")

# %%
get_output("POM sheet & profile, food grade FDA and EU10/2011, natural colour")

# %%
get_output("POM sheet & profile extrusion, food grade FDA and EU10/2011, natural colour")

# %%
get_output("high density, ensile modulus of 1200 mpa")

# %%
get_output("low density, cti plc1")

# %%
get_output("bmw bonnet")

# %%
get_output("bonnet")

# %%
get_output("bracket for light for consumer goods") # consumer goods should also be present in application but not an issue

# %%
get_output("bmw or ford")

# %%
get_output("grade for dental part (medical)") # medical can be feature / part of app

# %%
get_output("Akroloy carbon fiber PA6")

# %%
get_output("bmw")

# %%
get_output("gm / ford / benz")

# %%
get_output("alternative to DelrinDE9494")

# %%
get_output("celcon m90")

# %%
get_output("duracon m90")

# %%
get_output("offset duracon m90")

# %%
get_output("hfc9021")

# %%
get_output("eco-r")

# %%
get_output("8291-85TL")

# %%
get_output("PA6 with 20% recycling content")

# %%
# get_output("PA6/12 PTFE 30% Glass filled, 15% PTFE BK") # do not fix it. 
get_output("PA6/12 30% Glass filled, 15% PTFE BK") # 30% or 45% both are fine as query is wrong

# %%
get_output("aramide 30% and mf 15%") 
get_output("aramide 30% and md 15%")

# %%
get_output("lgf30 and cd15")

# %%
get_output("medical htn grade") # medical can be both feature or app # should we add industry in post processing?

# %%
get_output("nsf and celcon")

# %%
get_output("Light stabilized, heat resistant grade")

# %%
get_output("a3wg6")

# %%
get_output("high heat resistance")

# %%
get_output("high heat resistance, low density")

# %%
get_output("ten mod 1200 high heat resistance")

# %%
get_output("gf and cd")

# %%
get_output("heat resis uv")

# %%
get_output("nylon 6/10, extrusion, weatherseal")

# %%
get_output("flexural of 200 also consider a 15 % range")

# %%
get_output("tensile modulus 200 also consider a 20% range")

# %%
get_output("grade for abrasion sheet")

# %%
get_output("cti plc0")
# get_output("cti plc 0")

# %%
get_output("fr 1 v0") # difficult to handle

# %%
get_output("fr v0 at 6 mm thickness")

# %%
get_output("fr v0 , thickness of 5mm")

# %%
get_output("en6421")

# %%
get_output("en45545") # railway

# %%
get_output("nsf certified")

# %%
get_output("nsf approved")

# %%
get_output("water approved")

# %%
get_output("water approval")

# %%
get_output("elastomer port connector medical")

# %%
get_output("extrusion grade with uv resistance")

# %%
get_output("celanyl A2HH J7 GF15")

# %%
get_output("hf c9021")

# %%
get_output("tensile modulus tape 1200")

# %%
get_output("nsf")

# %%
get_output("tensile mod min 1200")

# %%
get_output("Dissipation factor 100Hz of 250")

# %%
get_output("grades with auto approvals")

# %%
get_output("grades that are auto approved")

# %%
get_output("grades that are automotive approved")

# %%
get_output("light for automotives")

# %%
get_output("light in automotives")

# %%
get_output("seal for battery")

# %%
get_output("grade for mirror button")

# %%
get_output("gf and mf 15")

# %%
get_output("zytel grades")

# %%
get_output("izod nb impact")

# %%
get_output("no break impact")

# %%
get_output("no break impact unnotched")

# %%
get_output("no break impact notched")

# %%
get_output("nb impact notched")

# %%
get_output("15702") # pre-processing will take care

# %%
get_output("6356")

# %%
get_output("13021") # pre-processing will take care

# %%
get_output("93016")

# %%
get_output("93017")

# %%
get_output("sheet & profile extrusion")

# %%
get_output("extrusion - sheet & profile")

# %%
get_output("QLIA5310020")

# %%
get_output("Q/LIA5310020")

# %%
get_output("Tensile stress at Yield : >55MPa, OEM spec: QLIA5310020")

# %%
get_output("low break elongation") # tensile strain at break

# %%
get_output("lcp grade bonding to pps")

# %%
get_output("impact strength")

# %%
get_output("VW50136")

# %%
get_output("hot water certification")

# %%
get_output("hot water")  # it is present in app but can be water certification as well # however query is not complete

# %%
get_output("is cra fr685nh1 bk591 available in japan")

# %%
test_queries = [ 'United Kingdom',
 'UK',
 'Georgia',
 'any uv resistant material available in macedonia?',
 '40% glass-filled fortron available in Hungary',
 'Italy',
 'PA for asian automobiles',
 'PA for italian automobiles',
 'POM available in estonia',
 'denmark sourced fortron',
 'Slovakia',
 'Sweden',
 'heat stabilized grade available in Malawi',
 'Hi flow Vectra obtainable in São Tomé and Príncipe',
 'Cameroon',
 'Mauritius',
 'Egypt',
 'bio-based, high flow material needed in UAE',
 'what grades are available in Qatar that can be used for a fuel cap?',
 'India',
 'Jordan',
 'Bhutan',
 'China',
 '40% glass-filled fortron available in s korea',
 'Japan',
 'Thailand',
 'Malaysia',
 'US sourced fortron',
 'U.S. sourced fortron',
 'POM available in canada',
 'material with water approval sold in mexico',
 'Brazil',
 'Chile',
 'Frankfurt',
 'heat stabilized grade available in Neuchâtel',
 'what grades are available in Jaipur that can be used for a fuel cap?',
 'Singapore',
 'material with water approval sold in taipei',
 'Chengdu',
 'Nanjing',
 'Fukuoka',
 'Edmonton',
 'Lawrence',
 'POM available in arica',
 'São Paulo',
 'Ecatepec de Morelos',]

# %%
for i in test_queries:
    print(i)
    get_output(i)
    print("#"*25,"\n")

# %%
print(eval(get_ner_gpt("PA for italian automobiles".lower())))

# %%
get_output("nylon 6/10, extrusion, weatherseal")

# %%
get_output("low friction grade")

# %%
print(eval(get_ner_gpt("low friction grade".lower())))

# %%
print(eval(get_ner_gpt("MI of 250".lower())))

# %%
print(eval(get_ner_gpt("fr hb".lower())))

# %%
get_output("tv led panel in NY")

# %%
get_output("performance pet n2r")

# %%
get_output("Mercedes-Benz Group (Daimier) and Mercedes-Benz dbl 2000")

# %%
get_output("Bosch, CATL, Changan, Chery-reference")

# %%
get_output("grades from all industries")

# %%
get_output("grades available worldwide")

# %%
get_output("busbar material available in all regions")

# %%
get_output("busbar material available in all industry")

# %%
get_output("busbar automotive available in all industry") #invalid query

# %%
get_output("technoprene grade")

# %%
get_output("technoprene gf40-pp hx grade") # do we want auto correction in grade?

# %%
get_output("conveyor belt barrel")

# %%
get_output("non halogen")

# %%
get_output("density 175")

# %%
get_output("polifor")

# %%
get_output("gf of load 10 to 30")

# %%
get_output("min+gf 30-60")

# %%
get_output("cfr-gf 20-60")

# %%
get_output("cfr-gf 20%")

# %%
get_output("lgf >20%")

# %%
get_output("min <20%")

# %%
get_output("rti <20")

# %%
get_output("rti >20")

# %%
get_output("rti 100 to 200")

# %%
get_output("rti 100 to 200 thickness 2mm to 4mm")
